# %%
import pandas
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_colwidth', 500)
df = pd.read_csv("tweets_20240814151958.csv")
df.head(2)
# Out:
#          user_name                      created at  favorite_count  \
# 0  Winkeldiefstal1  Wed Aug 14 13:09:12 +0000 2024               0
# 1    JerinTahapary  Wed Aug 14 09:07:09 +0000 2024               0
#
#                                                                                                        text  \
# 0                                   @BartMos @Belastingdienst @ingnl Ook gezien hoeveel fouten er in staan?
# 1  @ingnl @elisalocuta Beste, ik heb het weer geprobeerd om de App te openen, en het werkt nu gelukkig wel!
#
#                     id   in_reply_to  is_reply lang  view_count  retweet_count
# 0  1823708450628788401  1.823387e+18      True   nl           6              0
# 1  1823647539540697450  1.823647e+18      True   nl          30              0

# %%
suitable_tweets = df[(df.is_reply == False) & (df.lang == "nl")]
suitable_tweets[["text", "view_count", "lang"]].sort_values(by="view_count", ascending=False)
# Out:
#                                                                                                                                                                                                                                                                                                                 text  \
# 10   En ja hoor, meneer Roet gaat gewoon door met rondsturen van bedelbrieven namens Loterijverlies. Nu wil hij geld voor de ‘schikkig’ die hij is overeengekomen met de @Belastingdienst. Bij @ingnl is hij niet meer welkom, vandaar dat het geld nu overgemaakt moet worden naar ‘Finom’. https://t.co/D7XRuyAtxc
# 52                                                Voor bedrijven als @ASMLcompany, @Rabobank, @Shell, @ABNAMRO, @ingnl en @Heineken ligt hier toch een geweldige kans? Met een fractie van hun miljardenwinsten kunnen ze bijdragen aan ons topsportklimaat en een vleugje verbinding in NL. https://t.co/HGA8BLyh8E
# ...

# %%
len(suitable_tweets)
# Out:
# 94
